# %% [markdown]
# 利用 Python 存取 API
# 了解 Server Client 的架構與溝通方法
# 知道 HTTP Request & Response 的內容
# 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
# https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
# 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
#
# ### r.text 是字串格式，json.loads(r.text)是json格式

# %%
# requests
import requests

response = requests.get('https://api.github.com/events')
response.text
# Out:
# '[{"id":"16131740573","type":"WatchEvent","actor":{"id":2101780,"login":"matueranet","display_login":"matueranet","gravatar_id":"","url":"https://api.github.com/users/matueranet","avatar_url":"https://avatars.githubusercontent.com/u/2101780?"},"repo":{"id":240315046,"name":"jina-ai/jina","url":"https://api.github.com/repos/jina-ai/jina"},"payload":{"action":"started"},"public":true,"created_at":"2021-04-29T06:25:15Z","org":{"id":60539444,"login":"jina-ai","gravatar_id":"","url":"https://api.github.com/orgs/jina-ai","avatar_url":"https://avatars.githubusercontent.com/u/60539444?"}},{"id":"16131740559","type":"PushEvent","actor":{"id":31997505,"login":"cp2004","display_login":"cp2004","gravatar_id":"","url":"https://api.github.com/users/cp2004","avatar_url":"https://avatars.githubusercontent.com/u/31997505?"},"repo":{"id":272737259,"name":"cp2004/Octoprint-Upgrade-To-Py3","url":"https://api.github.com/repos/cp2004/Octoprint-Upgrade-To-Py3"},"payload":{"push_id":7007863662,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"ca9fa7c430281b1c3e3060ad91c57bd40ec91baf","before":"c0b6f9fc8049a58943c4d74528c4bbe47a536553","commits":[{"sha":"ca9fa7c430281b1c3e3060ad91c57bd40ec91baf","author":{"email":"31997505+cp2004@users.noreply.github.com","name":"Charlie Powell"},"message":" ✏️ Remove latest OctoPrint version","distinct":true,"url":"https://api.github.com/repos/cp2004/Octoprint-Upgrade-To-Py3/commits/ca9fa7c430281b1c3e3060ad91c57bd40ec91baf"}]},"public":true,"created_at":"2021-04-29T06:25:15Z"},{"id":"16131740558","type":"PushEvent","actor":{"id":66474943,"login":"lohithreddy2002","display_login":"lohithreddy2002","gravatar_id":"","url":"https://api.github.com/users/lohithreddy2002","avatar_url":"https://avatars.githubusercontent.com/u/66474943?"},"repo":{"id":362703394,"name":"lohithreddy2002/lohithreddy2002","url":"https://api.github.com/repos/lohithreddy2002/lohithreddy2002"},"payload":{"push_id":7007863670,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"fdcb1943eb60596408c872e0a86c3bbd3394cbdc","before":"1e8c77ac936921c3be4ffa3f6b6dfaa1a56753da","commits":[{"sha":"fdcb1943eb60596408c872e0a86c3bbd3394cbdc","author":{"email":"rocklohithreddy@gmail.com","name":"Lohith Reddy"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/lohithreddy2002/lohithreddy2002/commits/fdcb1943eb60596408c872e0a86c3bbd3394cbdc"}]},"public":true,"created_at":"2021-04-29T06:25:15Z"},{"id":"16131740554","type":"WatchEvent","actor":{"id":12287067,"login":"596672125","display_login":"596672125","gravatar_id":"","url":"https://api.github.com/users/596672125","avatar_url":"https://avatars.githubusercontent.com/u/12287067?"},"repo":{"id":97827246,"name":"Kotlin/kotlinx.serialization","url":"https://api.github.com/repos/Kotlin/kotlinx.serialization"},"payload":{"action":"started"},"public":true,"created_at":"2021-04-29T06:25:15Z","org":{"id":1446536,"login":"Kotlin","gravatar_id":"","url":"https://api.github.com/orgs/Kotlin","avatar_url":"https://avatars.githubusercontent.com/u/1446536?"}},{"id":"16131740545","type":"IssueCommentEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":295991523,"name":"moniqueaz/won-games-client","url":"https://api.github.com/repos/moniqueaz/won-games-client"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/moniqueaz/won-games-client/issues/167","repository_url":"https://api.github.com/repos/moniqueaz/won-games-client","labels_url":"https://api.github.com/repos/moniqueaz/won-games-client/issues/167/labels{/name}","comments_url":"https://api.github.com/repos/moniqueaz/won-games-client/issues/167/comments","events_url":"https://api.github.com/repos/moniqueaz/won-games-client/issues/167/events","html_url":"https://github.com/moniqueaz/won-games-client/pull/167","id":851050611,"node_ ...

# %%
# json.loads()
import json
data = json.loads(response.text)
data
# Out:
# [{'id': '16131740573',
#   'type': 'WatchEvent',
#   'actor': {'id': 2101780,
#    'login': 'matueranet',
#    'display_login': 'matueranet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/matueranet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2101780?'},
#   'repo': {'id': 240315046,
#    'name': 'jina-ai/jina',
#    'url': 'https://api.github.com/repos/jina-ai/jina'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z',
#   'org': {'id': 60539444,
#    'login': 'jina-ai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/jina-ai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60539444?'}},
#  {'id': '16131740559',
#   'type': 'PushEvent',
#   'actor': {'id': 31997505,
#    'login': 'cp2004',
#    'display_login': 'cp2004',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cp2004',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31997505?'},
#   'repo': {'id': 272737259,
#    'name': 'cp2004/Octoprint-Upgrade-To-Py3',
#    'url': 'https://api.github.com/repos/cp2004/Octoprint-Upgrade-To-Py3'},
#   'payload': {'push_id': 7007863662,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ca9fa7c430281b1c3e3060ad91c57bd40ec91baf',
#    'before': 'c0b6f9fc8049a58943c4d74528c4bbe47a536553',
#    'commits': [{'sha': 'ca9fa7c430281b1c3e3060ad91c57bd40ec91baf',
#      'author': {'email': '31997505+cp2004@users.noreply.github.com',
#       'name': 'Charlie Powell'},
#      'message': ' ✏️ Remove latest OctoPrint version',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cp2004/Octoprint-Upgrade-To-Py3/commits/ca9fa7c430281b1c3e3060ad91c57bd40ec91baf'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z'},
#  {'id': '16131740558',
#   'type': 'PushEvent',
#   'actor': {'id': 66474943,
#    'login': 'lohithreddy2002',
#    'display_login': 'lohithreddy2002',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lohithreddy2002',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66474943?'},
#   'repo': {'id': 362703394,
#    'name': 'lohithreddy2002/lohithreddy2002',
#    'url': 'https://api.github.com/repos/lohithreddy2002/lohithreddy2002'},
#   'payload': {'push_id': 7007863670,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fdcb1943eb60596408c872e0a86c3bbd3394cbdc',
#    'before': '1e8c77ac936921c3be4ffa3f6b6dfaa1a56753da',
#    'commits': [{'sha': 'fdcb1943eb60596408c872e0a86c3bbd3394cbdc',
#      'author': {'email': 'rocklohithreddy@gmail.com', 'name': 'Lohith Reddy'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lohithreddy2002/lohithreddy2002/commits/fdcb1943eb60596408c872e0a86c3bbd3394cbdc'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z'},
#  {'id': '16131740554',
#   'type': 'WatchEvent',
#   'actor': {'id': 12287067,
#    'login': '596672125',
#    'display_login': '596672125',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/596672125',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12287067?'},
#   'repo': {'id': 97827246,
#    'name': 'Kotlin/kotlinx.serialization',
#    'url': 'https://api.github.com/repos/Kotlin/kotlinx.serialization'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z',
#   'org': {'id': 1446536,
#    'login': 'Kotlin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Kotlin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1446536?'}},
#  {'id': '16131740545',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 295991523,
#    'name': 'moniqueaz/won-games-client',
#    'url': 'https://api.github.com/repos/moniqueaz/won-games-client'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/moniqueaz/won-games-client/issues/167',
#     'repository_url': 'https://api.github.com/repos/moniqueaz/won-games-client',
#     'labels_url': 'https://api.github.com/repos/moniqueaz/won-games-client/issues/167/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/moniqueaz/won-games-client/issues/167/comments',
#     'events_url': 'https://api.github.com/repos/moniqueaz/won-games-client/issues/167/events',
#     'html_url': 'https://github.com/moniqueaz/won-games-client/pull/167',
#     'id': 851050611,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjA5NTMxOTI5',
#     'number': 167,
#     'title': 'chore(deps): bump next from 9.5.3 to 10.1.3',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 2352660723,
#       'node_id': 'MDU6TGFiZWwyMzUyNjYwNzIz',
#       'url': 'https://api.github.com/repos/moniqueaz/won-games-client/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2021-04-06T06:35:26Z',
#     'updated_at': '2021-04-29T06:25:15Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/moniqueaz/won-games-client/pulls/167',
#      'html_url': 'https://github.com/moniqueaz/won-games-client/pull/167',
#      'diff_url': 'https://github.com/moniqueaz/won-games-client/pull/167.diff',
#      'patch_url': 'https://github.com/moniqueaz/won-games-client/pull/167.patch'},
#     'body': 'Bumps [next](https://github.com/vercel/next.js) from 9.5.3 to 10.1.3.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/vercel/next.js/releases">next\'s releases</a>.</em></p>\n<blockquote>\n<h2>v10.1.3</h2>\n<h3>Core Changes</h3>\n<ul>\n<li>Fix memory leak in image optimization: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23565">#23565</a></li>\n<li>Mark this.router protected: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23573">#23573</a></li>\n<li>Ensure has segments are allowed in destination: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23588">#23588</a></li>\n<li>Update decoder to correctly handle grayscale PNGs: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23393">#23393</a></li>\n<li>update webpack to 5.30: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23612">#23612</a></li>\n<li>Clean up RenderOptsPartial: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23614">#23614</a></li>\n</ul>\n<h3>Documentation Changes</h3>\n<ul>\n<li>Update router.md to improve a11y: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23611">#23611</a></li>\n</ul>\n<h3>Example Changes</h3>\n<ul>\n<li>Remove redundant prefresh dependency in with-preact example: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23567">#23567</a></li>\n<li>Delete examples/with-style-sheet directory: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23609">#23609</a></li>\n<li>Update custom-routes-proxying to use fallback rewrites: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23610">#23610</a></li>\n</ul>\n<h3>Credits</h3>\n<p>Huge thanks to <a href="https://github.com/shuding"><code>@\u200bshuding</code></a>, <a href="https://github.com/zephraph"><code>@\u200bzephraph</code></a>, <a href="https://github.com/timneutkens"><code>@\u200btimneutkens</code></a>, <a href="https://github.com/samrobbins85"><code>@\u200bsamrobbins85</code></a>, <a href="https://github.com/sokra"><code>@\u200bsokra</code></a>, and <a href="https://github.com/devknoll"><code>@\u200bdevknoll</code></a> for helping!</p>\n<h2>v10.1.3-canary.2</h2>\n<h3>Core Changes</h3>\n<ul>\n<li>Clean up RenderOptsPartial: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23614">#23614</a></li>\n</ul>\n<h3>Credits</h3>\n<p>Huge thanks to <a href="https://github.com/devknoll"><code>@\u200bdevknoll</code></a> for helping!</p>\n<h2>v10.1.3-canary.1</h2>\n<h3>Core Changes</h3>\n<ul>\n<li>Mark this.router protected: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23573">#23573</a></li>\n<li>Ensure has segments are allowed in destination: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23588">#23588</a></li>\n<li>Update decoder to correctly handle grayscale PNGs: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23393">#23393</a></li>\n<li>update webpack to 5.30: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23612">#23612</a></li>\n</ul>\n<h3>Documentation Changes</h3>\n<ul>\n<li>Update router.md to improve a11y: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23611">#23611</a></li>\n</ul>\n<h3>Example Changes</h3>\n<ul>\n<li>Remove redundant prefresh dependency in with-preact example: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23567">#23567</a></li>\n<li>Delete examples/with-style-sheet directory: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23609">#23609</a></li>\n<li>Update custom-routes-proxying to use fallback rewrites: <a href="https://github-redirect.dependabot.com/vercel/next.js/issues/23610">#23610</a></li>\n</ul>\n<!-- raw HTML omitted -->\n</blockquote>\n<p>... (truncated)</p>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href= ...
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/moniqueaz/won-games-client/issues/comments/828971887',
#     'html_url': 'https://github.com/moniqueaz/won-games-client/pull/167#issuecomment-828971887',
#     'issue_url': 'https://api.github.com/repos/moniqueaz/won-games-client/issues/167',
#     'id': 828971887,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDgyODk3MTg4Nw==',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-04-29T06:25:15Z',
#     'updated_at': '2021-04-29T06:25:15Z',
#     'author_association': 'NONE',
#     'body': 'Superseded by #179.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z'},
#  {'id': '16131740544',
#   'type': 'PushEvent',
#   'actor': {'id': 83389404,
#    'login': 'Ruofengware',
#    'display_login': 'Ruofengware',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ruofengware',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83389404?'},
#   'repo': {'id': 362712032,
#    'name': 'Ruofengware/zzu.github.io',
#    'url': 'https://api.github.com/repos/Ruofengware/zzu.github.io'},
#   'payload': {'push_id': 7007863655,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0039a3b11c8ceae40f06d0b92da84c77452c3993',
#    'before': '11504bf8b5e6f7b4e40fbb333be816405fcb6c10',
#    'commits': [{'sha': '0039a3b11c8ceae40f06d0b92da84c77452c3993',
#      'author': {'email': '83389404+Ruofengware@users.noreply.github.com',
#       'name': 'Ruofengware'},
#      'message': 'Create index1.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ruofengware/zzu.github.io/commits/0039a3b11c8ceae40f06d0b92da84c77452c3993'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z'},
#  {'id': '16131740538',
#   'type': 'PushEvent',
#   'actor': {'id': 6060791,
#    'login': 'dgafka',
#    'display_login': 'dgafka',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dgafka',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6060791?'},
#   'repo': {'id': 202167673,
#    'name': 'ecotoneframework/reference-guide',
#    'url': 'https://api.github.com/repos/ecotoneframework/reference-guide'},
#   'payload': {'push_id': 7007863652,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4d5fe9db6d590b60f31a98dfa874e2d6f7c391e9',
#    'before': '763d3a49481bea96a6d00beb27ab960f3e3da1ae',
#    'commits': [{'sha': '4d5fe9db6d590b60f31a98dfa874e2d6f7c391e9',
#      'author': {'email': 'dgafka.mail@gmail.com', 'name': 'Dariusz Gafka'},
#      'message': 'GitBook: [master] one page modified',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ecotoneframework/reference-guide/commits/4d5fe9db6d590b60f31a98dfa874e2d6f7c391e9'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z',
#   'org': {'id': 47981056,
#    'login': 'ecotoneframework',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ecotoneframework',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47981056?'}},
#  {'id': '16131740513',
#   'type': 'PushEvent',
#   'actor': {'id': 11470393,
#    'login': 'cjeker',
#    'display_login': 'cjeker',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cjeker',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11470393?'},
#   'repo': {'id': 166574383,
#    'name': 'openbgpd-portable/openbgpd-openbsd',
#    'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd'},
#   'payload': {'push_id': 7007863607,
#    'size': 1000,
#    'distinct_size': 0,
#    'ref': 'refs/heads/OPENBSD_2_5',
#    'head': '4d217b97c57ae72fcba8871f0575b7b9d185137e',
#    'before': 'bee6ce351c239c4980645830ec8a904ac2c47a27',
#    'commits': [{'sha': 'c7b4174100515efeab453cd2a5ab8d3d1f409181',
#      'author': {'email': '', 'name': 'tholo'},
#      'message': 'Use nanosleep(2)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/c7b4174100515efeab453cd2a5ab8d3d1f409181'},
#     {'sha': '6fbb102de8467d8ac62c928e97404a8a6f220f1f',
#      'author': {'email': '', 'name': 'provos'},
#      'message': 'skipped too many ids',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/6fbb102de8467d8ac62c928e97404a8a6f220f1f'},
#     {'sha': 'dace22a85c139a3023978ec1eca3ef72a4c1516f',
#      'author': {'email': '', 'name': 'kstailey'},
#      'message': 'less inaccurate',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/dace22a85c139a3023978ec1eca3ef72a4c1516f'},
#     {'sha': '9e3e3c46f5d972cf9431e3353d867c8dce069712',
#      'author': {'email': '', 'name': 'kstailey'},
#      'message': 'less inaccurate',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/9e3e3c46f5d972cf9431e3353d867c8dce069712'},
#     {'sha': '5bc5e19356f49a772a159cae73ac5c0448209074',
#      'author': {'email': '', 'name': 'kstailey'},
#      'message': 'added select(2) to see also, mostly to test cvs commit',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/5bc5e19356f49a772a159cae73ac5c0448209074'},
#     {'sha': '103973bd7d341fb0bdcd2bba18c1c7202f2caa69',
#      'author': {'email': '', 'name': 'deraadt'},
#      'message': 'md5 too (yeah, i know this is not perfect)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/103973bd7d341fb0bdcd2bba18c1c7202f2caa69'},
#     {'sha': 'ebeafe9903280e46ef36de912c6ba5d1ab8a768c',
#      'author': {'email': '', 'name': 'deraadt'},
#      'message': 'sd2 & sd3 in ramdisk too',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/ebeafe9903280e46ef36de912c6ba5d1ab8a768c'},
#     {'sha': 'b6265f16dde09caa1f01e2d7b14bc32b1cabad03',
#      'author': {'email': '', 'name': 'michaels'},
#      'message': 'correct declaration given for herror(3) and describe better.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/b6265f16dde09caa1f01e2d7b14bc32b1cabad03'},
#     {'sha': 'd371eead213e942d3b1e2b13c6b709a83559f977',
#      'author': {'email': '', 'name': 'michaels'},
#      'message': 'my keyboard made a typo.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/d371eead213e942d3b1e2b13c6b709a83559f977'},
#     {'sha': 'fe278342aea2c2113456aefd42e3a8d2f5ec0981',
#      'author': {'email': '', 'name': 'millert'},
#      'message': "COPY -> INSTALL_COPY and STRIP -> INSTALL_STRIP\nThis fixes namespace problems where STRIP is sometimes used as\nthe name of the strip(1) to use and other times used as\nthe flag to send install(1) when stripping (or not).\nCOPY doesn't have this problem (yet) but was poorly named.",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/fe278342aea2c2113456aefd42e3a8d2f5ec0981'},
#     {'sha': 'eb9c0a9769a517339ff64d28480cbb77f8fcacb7',
#      'author': {'email': '', 'name': 'deraadt'},
#      'message': 'handle hex-like hostnames',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/eb9c0a9769a517339ff64d28480cbb77f8fcacb7'},
#     {'sha': 'a0dcd0020d04b2c35dbd5767c7cf7ebd8109136d',
#      'author': {'email': '', 'name': 'angelos'},
#      'message': 'Typo and return value for arc4random().',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/a0dcd0020d04b2c35dbd5767c7cf7ebd8109136d'},
#     {'sha': '069de690612fc128051e3c3ed82867b11fb7393a',
#      'author': {'email': '', 'name': 'dima'},
#      'message': 'Fix typo.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/069de690612fc128051e3c3ed82867b11fb7393a'},
#     {'sha': '9345ca7403808c29b774269ae9552f0cf8a4249a',
#      'author': {'email': '', 'name': 'niklas'},
#      'message': 'Fix syntax problems, workaround sh bugs',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/9345ca7403808c29b774269ae9552f0cf8a4249a'},
#     {'sha': 'db7449429cf0af4518e2aaf3fa582228dae57bcb',
#      'author': {'email': '', 'name': 'deraadt'},
#      'message': 'careful buffer handling',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/db7449429cf0af4518e2aaf3fa582228dae57bcb'},
#     {'sha': '3c920084ec09f8c2cb5bbe6b00849aa43229f38f',
#      'author': {'email': '', 'name': 'deraadt'},
#      'message': 'oops',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/3c920084ec09f8c2cb5bbe6b00849aa43229f38f'},
#     {'sha': 'a07d6f03803b78052cdcf2c514fbeffcdfe116e5',
#      'author': {'email': '', 'name': 'niklas'},
#      'message': 'Fix miniroot.  Add a quantum disk provided by dima@openbsd.org,\nCleanup so all Quantum disks are now Capitalized.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/a07d6f03803b78052cdcf2c514fbeffcdfe116e5'},
#     {'sha': '9e367dced5284d11546343a9a6c74ddf4d15b3d8',
#      'author': {'email': '', 'name': 'tholo'},
#      'message': 'Be more careful with mixing types',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/9e367dced5284d11546343a9a6c74ddf4d15b3d8'},
#     {'sha': '35f85e5ce231878bc9bcb72f059a0bc950bbf98e',
#      'author': {'email': '', 'name': 'tholo'},
#      'message': 'Remove unused variables',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/35f85e5ce231878bc9bcb72f059a0bc950bbf98e'},
#     {'sha': 'b26d17ded7545472d8d735e7268c18df67caf617',
#      'author': {'email': '', 'name': 'tholo'},
#      'message': 'Be more careful about possible type promotion',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/openbgpd-portable/openbgpd-openbsd/commits/b26d17ded7545472d8d735e7268c18df67caf617'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z',
#   'org': {'id': 46848243,
#    'login': 'openbgpd-portable',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openbgpd-portable',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46848243?'}},
#  {'id': '16131740525',
#   'type': 'PushEvent',
#   'actor': {'id': 69549081,
#    'login': 'CaretSoftware',
#    'display_login': 'CaretSoftware',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CaretSoftware',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69549081?'},
#   'repo': {'id': 357718263,
#    'name': 'CaretSoftware/MooBooM',
#    'url': 'https://api.github.com/repos/CaretSoftware/MooBooM'},
#   'payload': {'push_id': 7007863642,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7954ecc66c255dfec1c21ad9f9655c8300f5ebab',
#    'before': '84c1ffa7e5d76c4f48431debc47bd3ec1862383e',
#    'commits': [{'sha': '7954ecc66c255dfec1c21ad9f9655c8300f5ebab',
#      'author': {'email': 'pbergsten@me.com', 'name': 'CaretSoftware'},
#      'message': 'Updated LevelSelects name in scene 1 & 2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CaretSoftware/MooBooM/commits/7954ecc66c255dfec1c21ad9f9655c8300f5ebab'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z'},
#  {'id': '16131740527',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 33906690,
#    'login': 'sesheta',
#    'display_login': 'sesheta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sesheta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33906690?'},
#   'repo': {'id': 331431178,
#    'name': 'thoth-station/socrates',
#    'url': 'https://api.github.com/repos/thoth-station/socrates'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/thoth-station/socrates/issues/11',
#     'repository_url': 'https://api.github.com/repos/thoth-station/socrates',
#     'labels_url': 'https://api.github.com/repos/thoth-station/socrates/issues/11/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/thoth-station/socrates/issues/11/comments',
#     'events_url': 'https://api.github.com/repos/thoth-station/socrates/issues/11/events',
#     'html_url': 'https://github.com/thoth-station/socrates/pull/11',
#     'id': 870655769,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjI1ODE2NDQx',
#     'number': 11,
#     'title': 'Automatic update of dependencies by Kebechet',
#     'user': {'login': 'khebhut[bot]',
#      'id': 64544372,
#      'node_id': 'MDM6Qm90NjQ1NDQzNzI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/62893?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/khebhut%5Bbot%5D',
#      'html_url': 'https://github.com/apps/khebhut',
#      'followers_url': 'https://api.github.com/users/khebhut%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/khebhut%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/khebhut%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/khebhut%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/khebhut%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/khebhut%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/khebhut%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/khebhut%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/khebhut%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 2694488701,
#       'node_id': 'MDU6TGFiZWwyNjk0NDg4NzAx',
#       'url': 'https://api.github.com/repos/thoth-station/socrates/labels/approved',
#       'name': 'approved',
#       'color': '0e8a16',
#       'default': False,
#       'description': 'Indicates a PR has been approved by an approver from all required OWNERS files.'},
#      {'id': 2674062042,
#       'node_id': 'MDU6TGFiZWwyNjc0MDYyMDQy',
#       'url': 'https://api.github.com/repos/thoth-station/socrates/labels/bot',
#       'name': 'bot',
#       'color': 'ededed',
#       'default': False,
#       'description': None},
#      {'id': 2943406281,
#       'node_id': 'MDU6TGFiZWwyOTQzNDA2Mjgx',
#       'url': 'https://api.github.com/repos/thoth-station/socrates/labels/ok-to-test',
#       'name': 'ok-to-test',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2021-04-29T06:25:03Z',
#     'updated_at': '2021-04-29T06:25:15Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/thoth-station/socrates/pulls/11',
#      'html_url': 'https://github.com/thoth-station/socrates/pull/11',
#      'diff_url': 'https://github.com/thoth-station/socrates/pull/11.diff',
#      'patch_url': 'https://github.com/thoth-station/socrates/pull/11.patch'},
#     'body': 'Kebechet has updated the depedencies to the latest version :rocket:\nThe direct dependencies updated in the pull request are -\nPackage Name | Old Version | Updated Version | Is Dev\n--- | --- | --- | ---\n**pygithub**|1.54.1|1.55|False\n\n\nThis Pull Request is based on a [Project Thoth GitHub App](https://github.com/marketplace/khebhut),\nand [Kebechet](https://github.com/thoth-station/kebechet) v1.2.4\n',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/thoth-station/socrates/issues/comments/828971881',
#     'html_url': 'https://github.com/thoth-station/socrates/pull/11#issuecomment-828971881',
#     'issue_url': 'https://api.github.com/repos/thoth-station/socrates/issues/11',
#     'id': 828971881,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDgyODk3MTg4MQ==',
#     'user': {'login': 'sesheta',
#      'id': 33906690,
#      'node_id': 'MDQ6VXNlcjMzOTA2Njkw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/33906690?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sesheta',
#      'html_url': 'https://github.com/sesheta',
#      'followers_url': 'https://api.github.com/users/sesheta/followers',
#      'following_url': 'https://api.github.com/users/sesheta/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sesheta/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sesheta/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sesheta/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sesheta/orgs',
#      'repos_url': 'https://api.github.com/users/sesheta/repos',
#      'events_url': 'https://api.github.com/users/sesheta/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sesheta/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-04-29T06:25:15Z',
#     'updated_at': '2021-04-29T06:25:15Z',
#     'author_association': 'MEMBER',
#     'body': '[APPROVALNOTIFIER] This PR is **APPROVED**\n\nApproval requirements bypassed by manually added approval.\n\nThis pull-request has been approved by: *<a href="https://github.com/thoth-station/socrates/pull/11#pullrequestreview-647847531" title="Approved">sefkhet-abwy[bot]</a>*\n\nThe full list of commands accepted by this bot can be found [here](https://go.k8s.io/bot-commands?repo=thoth-station%2Fsocrates).\n\nThe pull request process is described [here](https://git.k8s.io/community/contributors/guide/owners.md#the-code-review-process)\n\n<details >\nNeeds approval from an approver in each of these files:\n\n- **[OWNERS](https://github.com/thoth-station/socrates/blob/master/OWNERS)**\n\nApprovers can indicate their approval by writing `/approve` in a comment\nApprovers can cancel approval by writing `/approve cancel` in a comment\n</details>\n<!-- META={"approvers":["fridex"]} -->',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z',
#   'org': {'id': 36954363,
#    'login': 'thoth-station',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/thoth-station',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36954363?'}},
#  {'id': '16131740521',
#   'type': 'PushEvent',
#   'actor': {'id': 81202531,
#    'login': 'kddhi',
#    'display_login': 'kddhi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kddhi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81202531?'},
#   'repo': {'id': 350601136,
#    'name': 'kddhi/akd',
#    'url': 'https://api.github.com/repos/kddhi/akd'},
#   'payload': {'push_id': 7007863643,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f52709fba7fc74be91141d022298ad1433d01ca6',
#    'before': '632fbf2391b08f31f4298cfb17c47b4a1952e09d',
#    'commits': [{'sha': 'f52709fba7fc74be91141d022298ad1433d01ca6',
#      'author': {'email': '81202531+kddhi@users.noreply.github.com',
#       'name': 'kddhi'},
#      'message': '#',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kddhi/akd/commits/f52709fba7fc74be91141d022298ad1433d01ca6'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z'},
#  {'id': '16131740528',
#   'type': 'DeleteEvent',
#   'actor': {'id': 5753622,
#    'login': 'jnidzwetzki',
#    'display_login': 'jnidzwetzki',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jnidzwetzki',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5753622?'},
#   'repo': {'id': 45732002,
#    'name': 'jnidzwetzki/bboxdb',
#    'url': 'https://api.github.com/repos/jnidzwetzki/bboxdb'},
#   'payload': {'ref': 'dependabot/maven/org.eclipse.jetty-jetty-servlet-11.0.1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z'},
#  {'id': '16131740515',
#   'type': 'PushEvent',
#   'actor': {'id': 666516,
#    'login': 'bencao',
#    'display_login': 'bencao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bencao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/666516?'},
#   'repo': {'id': 358762220,
#    'name': 'opentvl/opentvl',
#    'url': 'https://api.github.com/repos/opentvl/opentvl'},
#   'payload': {'push_id': 7007863635,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2f0421c3534d2e60eb7a0ebfca07b20e2e089490',
#    'before': 'f5348cdc884b183280c5c736039869e4d7558fbb',
#    'commits': [{'sha': '5b61eee9b70c9e6a711907331ebb16d8fc9c927a',
#      'author': {'email': 'zhenhua.cao@certik.org', 'name': 'Zhenhua Cao'},
#      'message': 'add server database support',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/opentvl/opentvl/commits/5b61eee9b70c9e6a711907331ebb16d8fc9c927a'},
#     {'sha': '2f0421c3534d2e60eb7a0ebfca07b20e2e089490',
#      'author': {'email': 'zhenhua.cao@certik.org', 'name': 'Zhenhua Ben Cao'},
#      'message': 'Merge pull request #14 from opentvl/server_database\n\nadd server database support',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/opentvl/opentvl/commits/2f0421c3534d2e60eb7a0ebfca07b20e2e089490'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z',
#   'org': {'id': 82688775,
#    'login': 'opentvl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/opentvl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82688775?'}},
#  {'id': '16131740511',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 158792369,
#    'name': 'KiraLT/torrent-stream-server',
#    'url': 'https://api.github.com/repos/KiraLT/torrent-stream-server'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/KiraLT/torrent-stream-server/issues/133',
#     'repository_url': 'https://api.github.com/repos/KiraLT/torrent-stream-server',
#     'labels_url': 'https://api.github.com/repos/KiraLT/torrent-stream-server/issues/133/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/KiraLT/torrent-stream-server/issues/133/comments',
#     'events_url': 'https://api.github.com/repos/KiraLT/torrent-stream-server/issues/133/events',
#     'html_url': 'https://github.com/KiraLT/torrent-stream-server/pull/133',
#     'id': 862467696,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjE5MDM0Njk0',
#     'number': 133,
#     'title': 'Bump @testing-library/user-event from 12.3.0 to 13.1.5 in /frontend',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 2212971797,
#       'node_id': 'MDU6TGFiZWwyMjEyOTcxNzk3',
#       'url': 'https://api.github.com/repos/KiraLT/torrent-stream-server/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2021-04-20T06:35:41Z',
#     'updated_at': '2021-04-29T06:25:15Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/KiraLT/torrent-stream-server/pulls/133',
#      'html_url': 'https://github.com/KiraLT/torrent-stream-server/pull/133',
#      'diff_url': 'https://github.com/KiraLT/torrent-stream-server/pull/133.diff',
#      'patch_url': 'https://github.com/KiraLT/torrent-stream-server/pull/133.patch'},
#     'body': 'Bumps [@testing-library/user-event](https://github.com/testing-library/user-event) from 12.3.0 to 13.1.5.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/testing-library/user-event/releases"><code>@\u200btesting-library/user-event</code>\'s releases</a>.</em></p>\n<blockquote>\n<h2>v13.1.5</h2>\n<h2><a href="https://github.com/testing-library/user-event/compare/v13.1.4...v13.1.5">13.1.5</a> (2021-04-19)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>relax typing and throw error for unsupported elements (<a href="https://github-redirect.dependabot.com/testing-library/user-event/issues/649">#649</a>) (<a href="https://github.com/testing-library/user-event/commit/dc131600f90313a92d776cd4cd9e2233e0edbe6b">dc13160</a>)</li>\n</ul>\n<h2>v13.1.4</h2>\n<h2><a href="https://github.com/testing-library/user-event/compare/v13.1.3...v13.1.4">13.1.4</a> (2021-04-18)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li><strong>keyboard:</strong> recognize <code>checkbox</code>/<code>radio</code> as clickable inputs (<a href="https://github-redirect.dependabot.com/testing-library/user-event/issues/654">#654</a>) (<a href="https://github.com/testing-library/user-event/commit/35d996eebd431a5839eb5be0a79b0f5d069693b8">35d996e</a>)</li>\n</ul>\n<h2>v13.1.3</h2>\n<h2><a href="https://github.com/testing-library/user-event/compare/v13.1.2...v13.1.3">13.1.3</a> (2021-04-14)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>throw error when <code>click</code>/<code>hover</code> on <code>pointer-events: none</code> (<a href="https://github-redirect.dependabot.com/testing-library/user-event/issues/647">#647</a>) (<a href="https://github.com/testing-library/user-event/commit/6b2ce66939bc4f2f3fc6cbef954261b5e3fe89ae">6b2ce66</a>)</li>\n</ul>\n<h2>v13.1.2</h2>\n<h2><a href="https://github.com/testing-library/user-event/compare/v13.1.1...v13.1.2">13.1.2</a> (2021-04-09)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>replace references to <code>global.document</code> (<a href="https://github-redirect.dependabot.com/testing-library/user-event/issues/642">#642</a>) (<a href="https://github.com/testing-library/user-event/commit/c69a74a1404ca12bbd2d9fa6814c9cb49464fa01">c69a74a</a>)</li>\n</ul>\n<h2>v13.1.1</h2>\n<h2><a href="https://github.com/testing-library/user-event/compare/v13.1.0...v13.1.1">13.1.1</a> (2021-03-30)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li><strong>type:</strong> catch internal promise rejections (<a href="https://github-redirect.dependabot.com/testing-library/user-event/issues/635">#635</a>) (<a href="https://github.com/testing-library/user-event/commit/6ae18e31c03cc46e3af4d03dc3041604daa4e733">6ae18e3</a>)</li>\n</ul>\n<h2>v13.1.0</h2>\n<h1><a href="https://github.com/testing-library/user-event/compare/v13.0.16...v13.1.0">13.1.0</a> (2021-03-30)</h1>\n<h3>Features</h3>\n<ul>\n<li>support CSS pointer-events property (<a href="https://github-redirect.dependabot.com/testing-library/user-event/issues/631">#631</a>) (<a href="https://github.com/testing-library/user-event/commit/32e971226e41c8bb458d6f56982f3e603152cffc">32e9712</a>)</li>\n</ul>\n<h2>v13.0.16</h2>\n<h2><a href="https://github.com/testing-library/user-event/compare/v13.0.15...v13.0.16">13.0.16</a> (2021-03-25)</h2>\n<!-- raw HTML omitted -->\n</blockquote>\n<p>... (truncated)</p>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/testing-library/user-event/commit/dc131600f90313a92d776cd4cd9e2233e0edbe6b"><code>dc13160</code></a> fix: relax typing and throw error for unsupported elements (<a href="https://github-redirect.dependabot.com/testing-library/user-event/issues/649">#649</a>)</li>\n<li><a href="https://github.com/testing-library/user-event/commit/5e6d7db2583898ca74d076f79f471ba5c1f35836"><code>5e6d7db</code></a> chore: remove typings from PR checklist (<a href="https://github-redirect.dependabot.com/testing-library/user-event/issues/657">#657</a>)</li>\n<li><a href="https://github.com/testing-library/user-event/commit/33d3a00dde99faf7 ...
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/KiraLT/torrent-stream-server/issues/comments/828971882',
#     'html_url': 'https://github.com/KiraLT/torrent-stream-server/pull/133#issuecomment-828971882',
#     'issue_url': 'https://api.github.com/repos/KiraLT/torrent-stream-server/issues/133',
#     'id': 828971882,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDgyODk3MTg4Mg==',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-04-29T06:25:15Z',
#     'updated_at': '2021-04-29T06:25:15Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Superseded by #137.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z'},
#  {'id': '16131740488',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 311882347,
#    'name': 'ealcca/turnosApp',
#    'url': 'https://api.github.com/repos/ealcca/turnosApp'},
#   'payload': {'ref': 'dependabot/composer/laravel/framework-8.39.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-04-29T06:25:15Z'},
#  {'id': '16131740495',
#   'type': 'ForkEvent',
#   'actor': {'id': 53084840,
#    'login': 'nguyenphuminh',
#    'display_login': 'nguyenphuminh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nguyenphuminh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53084840?'},
#   'repo': {'id': 362698901,
#    'name': 'joliorg/joliorg.github.io',
#    'url': 'https://api.github.com/repos/joliorg/joliorg.github.io'},
#   'payload': {'forkee': {'id': 362712348,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkzNjI3MTIzNDg=',
#     'name': 'joliorg.github.io',
#     'full_name': 'nguyenphuminh/joliorg.github.io',
#     'private': False,
#     'owner': {'login': 'nguyenphuminh',
#      'id': 53084840,
#      'node_id': 'MDQ6VXNlcjUzMDg0ODQw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/53084840?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nguyenphuminh',
#      'html_url': 'https://github.com/nguyenphuminh',
#      'followers_url': 'https://api.github.com/users/nguyenphuminh/followers',
#      'following_url': 'https://api.github.com/users/nguyenphuminh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nguyenphuminh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nguyenphuminh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nguyenphuminh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nguyenphuminh/orgs',
#      'repos_url': 'https://api.github.com/users/nguyenphuminh/repos',
#      'events_url': 'https://api.github.com/users/nguyenphuminh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nguyenphuminh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/nguyenphuminh/joliorg.github.io',
#     'description': "Official Jolio's website",
#     'fork': True,
#     'url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io',
#     'forks_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/forks',
#     'keys_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/teams',
#     'hooks_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/hooks',
#     'issue_events_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/events',
#     'assignees_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/tags',
#     'blobs_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/languages',
#     'stargazers_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/stargazers',
#     'contributors_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/contributors',
#     'subscribers_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/subscribers',
#     'subscription_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/subscription',
#     'commits_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/merges',
#     'archive_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/downloads',
#     'issues_url': 'https://api.github.com/repos/nguyenphuminh/joliorg.github.io/issues{/number}',
# ...
#      'comments': {'href': 'https://api.github.com/repos/join-com/grpc/issues/15/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/join-com/grpc/pulls/15/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/join-com/grpc/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/join-com/grpc/pulls/15/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/join-com/grpc/statuses/0c692860342c725469181ca8eac7d783a833e6fe'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 64,
#     'deletions': 14,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2021-04-29T06:25:14Z',
#   'org': {'id': 34453619,
#    'login': 'join-com',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/join-com',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34453619?'}},
#  {'id': '16131740436',
#   'type': 'ForkEvent',
#   'actor': {'id': 79388388,
#    'login': 'tangcb26',
#    'display_login': 'tangcb26',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tangcb26',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79388388?'},
#   'repo': {'id': 362562019,
#    'name': 'CSE110-SP21/Lab5',
#    'url': 'https://api.github.com/repos/CSE110-SP21/Lab5'},
#   'payload': {'forkee': {'id': 362712346,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkzNjI3MTIzNDY=',
#     'name': 'Lab5',
#     'full_name': 'tangcb26/Lab5',
#     'private': False,
#     'owner': {'login': 'tangcb26',
#      'id': 79388388,
#      'node_id': 'MDQ6VXNlcjc5Mzg4Mzg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/79388388?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tangcb26',
#      'html_url': 'https://github.com/tangcb26',
#      'followers_url': 'https://api.github.com/users/tangcb26/followers',
#      'following_url': 'https://api.github.com/users/tangcb26/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tangcb26/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tangcb26/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tangcb26/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tangcb26/orgs',
#      'repos_url': 'https://api.github.com/users/tangcb26/repos',
#      'events_url': 'https://api.github.com/users/tangcb26/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tangcb26/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/tangcb26/Lab5',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/tangcb26/Lab5',
#     'forks_url': 'https://api.github.com/repos/tangcb26/Lab5/forks',
#     'keys_url': 'https://api.github.com/repos/tangcb26/Lab5/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/tangcb26/Lab5/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/tangcb26/Lab5/teams',
#     'hooks_url': 'https://api.github.com/repos/tangcb26/Lab5/hooks',
#     'issue_events_url': 'https://api.github.com/repos/tangcb26/Lab5/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/tangcb26/Lab5/events',
#     'assignees_url': 'https://api.github.com/repos/tangcb26/Lab5/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/tangcb26/Lab5/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/tangcb26/Lab5/tags',
#     'blobs_url': 'https://api.github.com/repos/tangcb26/Lab5/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/tangcb26/Lab5/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/tangcb26/Lab5/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/tangcb26/Lab5/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/tangcb26/Lab5/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/tangcb26/Lab5/languages',
#     'stargazers_url': 'https://api.github.com/repos/tangcb26/Lab5/stargazers',
#     'contributors_url': 'https://api.github.com/repos/tangcb26/Lab5/contributors',
#     'subscribers_url': 'https://api.github.com/repos/tangcb26/Lab5/subscribers',
#     'subscription_url': 'https://api.github.com/repos/tangcb26/Lab5/subscription',
#     'commits_url': 'https://api.github.com/repos/tangcb26/Lab5/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/tangcb26/Lab5/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/tangcb26/Lab5/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/tangcb26/Lab5/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/tangcb26/Lab5/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/tangcb26/Lab5/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/tangcb26/Lab5/merges',
#     'archive_url': 'https://api.github.com/repos/tangcb26/Lab5/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/tangcb26/Lab5/downloads',
#     'issues_url': 'https://api.github.com/repos/tangcb26/Lab5/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/tangcb26/Lab5/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/tangcb26/Lab5/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/tangcb26/Lab5/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/tangcb26/Lab5/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/tangcb26/Lab5/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/tangcb26/Lab5/deployments',
#     'created_at': '2021-04-29T06:25:14Z',
#     'updated_at': '2021-04-28T21:09:13Z',
#     'pushed_at': '2021-04-28T22:59:35Z',
#     'git_url': 'git://github.com/tangcb26/Lab5.git',
#     'ssh_url': 'git@github.com:tangcb26/Lab5.git',
#     'clone_url': 'https://github.com/tangcb26/Lab5.git',
#     'svn_url': 'https://github.com/tangcb26/Lab5',
#     'homepage': None,
#     'size': 135,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2021-04-29T06:25:14Z',
#   'org': {'id': 82006167,
#    'login': 'CSE110-SP21',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CSE110-SP21',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82006167?'}},
#  {'id': '16131740433',
#   'type': 'PushEvent',
#   'actor': {'id': 82385067,
#    'login': 'uttamyadavabcdef',
#    'display_login': 'uttamyadavabcdef',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/uttamyadavabcdef',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82385067?'},
#   'repo': {'id': 357184646,
#    'name': 'uttamyadavabcdef/newrepo',
#    'url': 'https://api.github.com/repos/uttamyadavabcdef/newrepo'},
#   'payload': {'push_id': 7007863611,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '51547e3f3107369c15de66cb99c104eb596c4064',
#    'before': 'bb4fb43f88103fc2a78dea47a3b444ad64ef3131',
#    'commits': [{'sha': '51547e3f3107369c15de66cb99c104eb596c4064',
#      'author': {'email': '82385067+uttamyadavabcdef@users.noreply.github.com',
#       'name': 'uttamyadavabcdef'},
#      'message': 'Create howzat4.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/uttamyadavabcdef/newrepo/commits/51547e3f3107369c15de66cb99c104eb596c4064'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:14Z'},
#  {'id': '16131740435',
#   'type': 'PushEvent',
#   'actor': {'id': 6749661,
#    'login': 'test987987',
#    'display_login': 'test987987',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/test987987',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6749661?'},
#   'repo': {'id': 63269222,
#    'name': 'test987987/test100',
#    'url': 'https://api.github.com/repos/test987987/test100'},
#   'payload': {'push_id': 7007863608,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/csr-mirror',
#    'head': '0192d8fa9bb28e54468c83e9771012767bd2d395',
#    'before': '2c6f687d07be2e1f7925be0574e7ffe7af27f6b7',
#    'commits': [{'sha': '0192d8fa9bb28e54468c83e9771012767bd2d395',
#      'author': {'email': 'gerritcodereview-prober@gerritcodereview-prober.iam.gserviceaccount.com',
#       'name': 'gerritcodereview-prober@gerritcodereview-prober.iam.gserviceaccount.com'},
#      'message': 'adding timestamp file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/test987987/test100/commits/0192d8fa9bb28e54468c83e9771012767bd2d395'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:14Z'},
#  {'id': '16131740443',
#   'type': 'ForkEvent',
#   'actor': {'id': 13215166,
#    'login': 'zhenpingfeng',
#    'display_login': 'zhenpingfeng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhenpingfeng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13215166?'},
#   'repo': {'id': 282114315,
#    'name': 'ccyanxyz/rsex',
#    'url': 'https://api.github.com/repos/ccyanxyz/rsex'},
#   'payload': {'forkee': {'id': 362712347,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkzNjI3MTIzNDc=',
#     'name': 'rsex',
#     'full_name': 'zhenpingfeng/rsex',
#     'private': False,
#     'owner': {'login': 'zhenpingfeng',
#      'id': 13215166,
#      'node_id': 'MDQ6VXNlcjEzMjE1MTY2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/13215166?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/zhenpingfeng',
#      'html_url': 'https://github.com/zhenpingfeng',
#      'followers_url': 'https://api.github.com/users/zhenpingfeng/followers',
#      'following_url': 'https://api.github.com/users/zhenpingfeng/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/zhenpingfeng/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/zhenpingfeng/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/zhenpingfeng/subscriptions',
#      'organizations_url': 'https://api.github.com/users/zhenpingfeng/orgs',
#      'repos_url': 'https://api.github.com/users/zhenpingfeng/repos',
#      'events_url': 'https://api.github.com/users/zhenpingfeng/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/zhenpingfeng/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/zhenpingfeng/rsex',
#     'description': 'Cryptocurrency exchanges API wrapped in Rust.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/zhenpingfeng/rsex',
#     'forks_url': 'https://api.github.com/repos/zhenpingfeng/rsex/forks',
#     'keys_url': 'https://api.github.com/repos/zhenpingfeng/rsex/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/zhenpingfeng/rsex/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/zhenpingfeng/rsex/teams',
#     'hooks_url': 'https://api.github.com/repos/zhenpingfeng/rsex/hooks',
#     'issue_events_url': 'https://api.github.com/repos/zhenpingfeng/rsex/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/zhenpingfeng/rsex/events',
#     'assignees_url': 'https://api.github.com/repos/zhenpingfeng/rsex/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/zhenpingfeng/rsex/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/zhenpingfeng/rsex/tags',
#     'blobs_url': 'https://api.github.com/repos/zhenpingfeng/rsex/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/zhenpingfeng/rsex/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/zhenpingfeng/rsex/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/zhenpingfeng/rsex/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/zhenpingfeng/rsex/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/zhenpingfeng/rsex/languages',
#     'stargazers_url': 'https://api.github.com/repos/zhenpingfeng/rsex/stargazers',
#     'contributors_url': 'https://api.github.com/repos/zhenpingfeng/rsex/contributors',
#     'subscribers_url': 'https://api.github.com/repos/zhenpingfeng/rsex/subscribers',
#     'subscription_url': 'https://api.github.com/repos/zhenpingfeng/rsex/subscription',
#     'commits_url': 'https://api.github.com/repos/zhenpingfeng/rsex/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/zhenpingfeng/rsex/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/zhenpingfeng/rsex/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/zhenpingfeng/rsex/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/zhenpingfeng/rsex/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/zhenpingfeng/rsex/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/zhenpingfeng/rsex/merges',
#     'archive_url': 'https://api.github.com/repos/zhenpingfeng/rsex/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/zhenpingfeng/rsex/downloads',
#     'issues_url': 'https://api.github.com/repos/zhenpingfeng/rsex/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/zhenpingfeng/rsex/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/zhenpingfeng/rsex/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/zhenpingfeng/rsex/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/zhenpingfeng/rsex/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/zhenpingfeng/rsex/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/zhenpingfeng/rsex/deployments',
#     'created_at': '2021-04-29T06:25:14Z',
#     'updated_at': '2021-04-29T03:40:43Z',
#     'pushed_at': '2020-12-24T05:23:11Z',
#     'git_url': 'git://github.com/zhenpingfeng/rsex.git',
#     'ssh_url': 'git@github.com:zhenpingfeng/rsex.git',
#     'clone_url': 'https://github.com/zhenpingfeng/rsex.git',
#     'svn_url': 'https://github.com/zhenpingfeng/rsex',
#     'homepage': '',
#     'size': 41,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2021-04-29T06:25:14Z'},
#  {'id': '16131740431',
#   'type': 'PushEvent',
#   'actor': {'id': 35442123,
#    'login': 'MDAM182',
#    'display_login': 'MDAM182',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MDAM182',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35442123?'},
#   'repo': {'id': 132501882,
#    'name': 'MDAM182/learn-co-sandbox',
#    'url': 'https://api.github.com/repos/MDAM182/learn-co-sandbox'},
#   'payload': {'push_id': 7007863596,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '2552a0f53e6dbe90cc5b6b5d374a88baa6373ae2',
#    'before': '07a98669797082eed44a8b9a2c023a4a60c5b658',
#    'commits': [{'sha': '2552a0f53e6dbe90cc5b6b5d374a88baa6373ae2',
#      'author': {'email': 'mdam2345@gmail.com', 'name': 'Michael Morris'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MDAM182/learn-co-sandbox/commits/2552a0f53e6dbe90cc5b6b5d374a88baa6373ae2'}]},
#   'public': True,
#   'created_at': '2021-04-29T06:25:14Z'}]

# %% [markdown]
# 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
# https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
payload={
    'key1':'value1',
    'key2':'value2'
}
response = requests.get('http://httpbin.org/get',params=payload)
data = json.loads(response.text)
data
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.24.0',
#   'X-Amzn-Trace-Id': 'Root=1-608a55b7-5e5999b0274c6aa11aab2be9'},
#  'origin': '110.26.224.119',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
response = requests.post('http://httpbin.org/post', data={'key':'value'})
#data = json.loads(response.text)
#data
data = json.loads(response.text)
data
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.24.0',
#   'X-Amzn-Trace-Id': 'Root=1-608a5633-5ae646fc6ca546de316aa8e8'},
#  'json': None,
#  'origin': '110.26.224.119',
#  'url': 'http://httpbin.org/post'}
